# %%
import imaplib
import getpass
import email

from email.header import decode_header, make_header

# %% [markdown]
# ## Подключениек серверу IMAP

# %%
imap = imaplib.IMAP4_SSL('imap.gmail.com')
imap.login('widosmile@gmail.com', getpass.getpass())
# Out:
# ········
# ('OK', [b'widosmile@gmail.com authenticated (Success)'])

# %% [markdown]
# ## Список доступных папок
# Junk - это спам
# Проблема - название ящика для подключения имеет уникальное значение для каждого пользователя

# %%
imap_list = imap.list(pattern='*')

# %%
imap_list
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" "INBOX"',
#   b'(\\HasNoChildren) "/" "Notes"',
#   b'(\\HasChildren \\Noselect) "/" "[Gmail]"',
#   b'(\\HasNoChildren \\Important) "/" "[Gmail]/&BBIEMAQ2BD0EPgQ1-"',
#   b'(\\All \\HasNoChildren) "/" "[Gmail]/&BBIEQQRP- &BD8EPgRHBEIEMA-"',
#   b'(\\HasNoChildren \\Trash) "/" "[Gmail]/&BBoEPgRABDcEOAQ9BDA-"',
#   b'(\\HasNoChildren \\Sent) "/" "[Gmail]/&BB4EQgQ,BEAEMAQyBDsENQQ9BD0ESwQ1-"',
#   b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/&BB8EPgQ8BDUERwQ1BD0EPQRLBDU-"',
#   b'(\\HasNoChildren \\Junk) "/" "[Gmail]/&BCEEPwQwBDw-"',
#   b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/&BCcENQRABD0EPgQyBDgEOgQ4-"'])

# %% [markdown]
# ### Встроеные методы не позволяют выбирать по началу заголовка, пришлось написать функцию самому
# Однако, судя по информации и примерах кода в интернете, в некоторых случаях можно по общему имени выбирать (у меня не вышло)

# %%
def get_foldel_name(imap_list, general_name):
    result = []
    
    for i in imap_list[1]:
        l = i.decode().split(' "/" ')
        if general_name in l[0]:
            result.append((l[0], l[1]))
            
    return tuple(result)

# %% [markdown]
# # Spam

# %%
spam_folder = get_foldel_name(imap_list, 'Junk')
spam_folder
# Out:
# (('(\\HasNoChildren \\Junk)', '"[Gmail]/&BCEEPwQwBDw-"'),)

# %%
imap.select(spam_folder[0][1])
# Out:
# ('OK', [b'6'])

# %%
ids = imap.search(None, 'ALL')
ids
# Out:
# ('OK', [b'1 2 3 4 5 6'])

# %%
post_ids = ids[1][0].decode().split(' ')
post_ids = [p_id.encode() for p_id in post_ids]
post_ids
# Out:
# [b'1', b'2', b'3', b'4', b'5', b'6']

# %%
status, letter = imap.fetch(post_ids[0], '(RFC822)')
status, letter
# Out:
# ('OK',
#  [(b'1 (RFC822 {190391}',
#    b'Delivered-To: widosmile@gmail.com\r\nReceived: by 2002:adf:8062:0:0:0:0:0 with SMTP id 89csp4014214wrk;\r\n        Tue, 29 Sep 2020 01:18:21 -0700 (PDT)\r\nX-Google-Smtp-Source: ABdhPJyO1ic7vLUQCDRxwkvR3j80X5DHqsDefx+GcTa99jPiDzuHGoZaBRC+UW4hMmacJRgbIg9d\r\nX-Received: by 2002:a19:ca1e:: with SMTP id a30mr730797lfg.575.1601367501512;\r\n        Tue, 29 Sep 2020 01:18:21 -0700 (PDT)\r\nARC-Seal: i=1; a=rsa-sha256; t=1601367501; cv=none;\r\n        d=google.com; s=arc-20160816;\r\n        b=\r\nARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;\r\n        h=mime-version:subject:to:from:date:message-id:feedback-id:list-post\r\n         :list-archive:list-subscribe:list-unsubscribe:list-issue:list-id\r\n         :precedence:dkim-signature:dkim-signature;\r\n        bh=sxvXVXv6lSQPfzOo0rJLRmnw8tOAORDO9f/zpnTZug4=;\r\n        b=\r\nARC-Authentication-Results: i=1; mx.google.com;\r\n       dkim=pass header.i=@mail.psndsy.ru header.s=sndsy201706 header.b=rLrs9FJ1;\r\n       dkim=pass header.i=@news.ozon.ru header.s=ozon.49 header.b="SGXkRe/H";\r\n       spf=pass (google.com: domain of email-pegate-fhkluiwc6xgnamw6zamcpq2629031601367494-ozon@news.ozon.ru designates 185.235.29.16 as permitted sender) smtp.mailfrom=email-pegate-fHkLUiwC6xGNaMw6zamcPQ2629031601367494-ozon@news.ozon.ru;\r\n       dmarc=pass (p=QUARANTINE sp=QUARANTINE dis=NONE) header.from=news.ozon.ru\r\nReturn-Path: <email-pegate-fHkLUiwC6xGNaMw6zamcPQ2629031601367494-ozon@news.ozon.ru>\r\nReceived: from myyp16.news.ozon.ru (myyp16.news.ozon.ru. [185.235.29.16])\r\n        by mx.google.com with ESMTPS id y17si1281735lfy.453.2020.09.29.01.18.21\r\n        for <widosmile@gmail.com>\r\n        (version=TLS1_2 cipher=ECDHE-ECDSA-AES128-GCM-SHA256 bits=128/128);\r\n        Tue, 29 Sep 2020 01:18:21 -0700 (PDT)\r\nReceived-SPF: pass (google.com: domain of email-pegate-fhkluiwc6xgnamw6zamcpq2629031601367494-ozon@news.ozon.ru designates 185.235.29.16 as permitted sender) client-ip=185.235.29.16;\r\nAuthentication-Results: mx.google.com;\r\n       dkim=pass header.i=@mail.psndsy.ru header.s=sndsy201706 header.b=rLrs9FJ1;\r\n       dkim=pass header.i=@news.ozon.ru header.s=ozon.49 header.b="SGXkRe/H";\r\n       spf=pass (google.com: domain of email-pegate-fhkluiwc6xgnamw6zamcpq2629031601367494-ozon@news.ozon.ru designates 185.235.29.16 as permitted sender) smtp.mailfrom=email-pegate-fHkLUiwC6xGNaMw6zamcPQ2629031601367494-ozon@news.ozon.ru;\r\n       dmarc=pass (p=QUARANTINE sp=QUARANTINE dis=NONE) header.from=news.ozon.ru\r\nReceived: id 1A638FA82F7-1601367497\r\nReturn-Path: email-pegate-fHkLUiwC6xGNaMw6zamcPQ2629031601367494-ozon@news.ozon.ru\r\nDKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed; d=mail.psndsy.ru; s=sndsy201706;\r\n\tt=1601367497; bh=sxvXVXv6lSQPfzOo0rJLRmnw8tOAORDO9f/zpnTZug4=;\r\n\th=Precedence:List-Id:List-Issue:List-Unsubscribe:List-Subscribe:\r\n\t List-Archive:List-Post:X-Felis-L:X-rpcampaign:X-Mailru-Msgtype:\r\n\t Feedback-Id:Message-Id:Date:From:To:Subject:MIME-Version:\r\n\t Content-Type;\r\n\tb=rLrs9FJ1OkGBM4eQiJgLjdfqNnnLCZrP2SLu0QX1HFmz+8qx9DFYMraiZLISqWSB1\r\n\t FJKazIMxphIdrtlZLhtj8ZO7H74IDynm05sYMZ ...
#   b')'])

# %% [markdown]
# ## Letter parsing
# Используем модуль email

# %%
msg = email.message_from_bytes(letter[0][1], _class = email.message.EmailMessage)
msg

# %%
msg['Subject']
# Out:
# '=?utf-8?Q?=E2=9C=A8=D0=9B=D0=A3=D0=A7=D0=A8=D0=98=D0=95=20?=\r\n =?utf-8?Q?=D0=A6=D0=95=D0=9D=D0=AB=20?=\r\n =?utf-8?Q?=D0=B7=D0=B4=D0=B5=D1=81=D1=8C=20?=\r\n =?utf-8?Q?=E2=9E=9C=E2=9E=9C=E2=9E=9C?='

# %%
parsed_letter = dict(msg)
print('keys: ', parsed_letter.keys())
#parsed_letter
# Out:
# keys:  dict_keys(['Delivered-To', 'Received', 'X-Google-Smtp-Source', 'X-Received', 'ARC-Seal', 'ARC-Message-Signature', 'ARC-Authentication-Results', 'Return-Path', 'Received-SPF', 'Authentication-Results', 'DKIM-Signature', 'Precedence', 'List-Id', 'List-Issue', 'List-Unsubscribe', 'List-Subscribe', 'List-Archive', 'List-Post', 'X-Felis-L', 'X-rpcampaign', 'X-Mailru-Msgtype', 'Feedback-Id', 'Message-Id', 'Date', 'From', 'To', 'Subject', 'MIME-Version', 'Content-Type'])

# %% [markdown]
# ### Пример оновных значений
# Поля в imap закодированы в MIME формате
# Использую decode_header
# __!__ В return[0][1] возвращает изначальную кодировку

# %%
for key in parsed_letter.keys():
    
    parsed_letter[key] = str(make_header(decode_header(parsed_letter[key])))

# %%
print('From: ', parsed_letter['From'])
#print('Sender: ', parsed_letter['Sender'])
print('Subject: ', parsed_letter['Subject']) 
print('Date: ', parsed_letter['Date']) 
print('Content-Type: ', parsed_letter['Content-Type'])
# Out:
# From:  Роман Павлов | SF Education <education@sf.education>
# Subject:  ⚡️ Анонсы недели, которые вы не захотите пропустить
# Date:  Tue, 22 Sep 2020 11:10:35 +0000 (GMT)
# Content-Type:  multipart/alternative;
#  boundary="===============5354314217074122774=="

# %%
msg.get_payload()
# Out:
# [<email.message.EmailMessage at 0x7f024a2cecc0>,
#  <email.message.EmailMessage at 0x7f024a2cec88>,
#  <email.message.EmailMessage at 0x7f024a2cedd8>]

# %% [markdown]
# ### Оставшиеся закодированными байты никакой информации не несут (все содержимое письма здесь присутствует)

# %% [markdown]
# ### Однако тело может быть закодировано уже в другой кодировке (Отличие '=?utf-8?Q?' и '=?utf-8?b?' в начале)
# ### Кроме этого тело может состоять как из одной части, так и из нескольких (в случае нескольких нужно дополнительно найти нужное и декодировать его. Части могут как состоять из мусорных элементов, наподобие ?,!,<, так и пердставлять собой текст письма в разном формате)
# Чтобы бороться с данной проблемой, написана функция read_body()
# Ниже показан пример письма из нескольких частей

# %%
c = msg.get_body(preferencelist=('plain', 'html'))

# %%
msg.get_payload()[0].get_payload(decode=True).decode('utf-8','ignore')
# Out:
# ''

# %%
msg.get_payload()[1].get_payload(decode=True).decode('utf-8','ignore')
# Out:
# 'new Дайджест >>\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0 ...

# %%
msg.get_payload()[2].get_payload(decode=True).decode('utf-8','ignore')
# Out:
# '<!DOCTYPE html>\r\n<html xmlns:o="urn:schemas-microsoft-com:office:office" style="width:100%;font-family:tahoma, verdana, segoe, sans-serif;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%;padding:0;Margin:0">\r\n<head>\r\n<meta charset="UTF-8">\r\n<meta content="width=device-width, initial-scale=1" name="viewport">\r\n<meta name="x-apple-disable-message-reformatting">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta content="telephone=no" name="format-detection">\r\n<title>new Дайджест</title>\r\n<!--[if (mso 16)]> <style type="text/css"> a {text-decoration: none;} </style> <![endif]--><!--[if gte mso 9]><style>sup { font-size: 100% !important; }</style><![endif]--><!--[if gte mso 9]> <xml> <o:OfficeDocumentSettings> <o:AllowPNG></o:AllowPNG> <o:PixelsPerInch>96</o:PixelsPerInch> </o:OfficeDocumentSettings> </xml> <![endif]-->\r\n\r\n<style type="text/css">\r\n .rollover:hover .rollover-first { max-height:0px!important; display:none!important; } .rollover:hover .rollover-second { max-height:none!important; display:block!important; } #outlook a { padding:0; } .ExternalClass { width:100%; } .ExternalClass, .ExternalClass p, .ExternalClass span, .ExternalClass font, .ExternalClass td, .ExternalClass div { line-height:100%; } .es-button { mso-style-priority:100!important; text-decoration:none!important; } a[x-apple-data-detectors] { color:inherit!important; text-decoration:none!important; font-size:inherit!important; font-family:inherit!important; font-weight:inherit!important; line-height:inherit!important; } .es-desk-hidden { display:none; float:left; overflow:hidden; width:0; max-height:0; line-height:0; mso-hide:all; } .es-button-border:hover { border-style:solid solid solid solid!important; background:#0e6ec2!important; border-color:#42d159 #42d159 #42d159 #42d159!important; } .es-button-border:hover a.es-button { background:#0e6ec2!important; border-color:#0e6ec2!important; } td .es-button-border:hover a.es-button-1 { background:#e0ab0f!important; border-color:#e0ab0f!important; } td .es-button-border-2:hover { background:#e0ab0f!important; } td .es-button-border:hover a.es-button-3 { background:#0b5394!important; border-color:#0b5394!important; } td .es-button-border-4:hover { background:#0b5394!important; } td .es-button-border:hover a.es-button-5 { background:#cc0000!important; border-color:#cc0000!important; } td .es-button-border-6:hover { background:#cc0000!important; } td .es-button-border:hover a.es-button-7 { background:#ac0803!important; border-color:#ac0803!important; } td .es-button-border-8:hover { background:#ac0803!important; } @media only screen and (max-width:600px) {.st-br { padding-left:10px!important; padding-right:10px!important } p, ul li, ol li, a { font-size:16px!important; line-height:120%!important } h1 { font-size:28px!important; text-align:center; line-height:120%!important } h2 { font-size:24px!important; text-align:center; line-height:120%!important } h3 { font-size:18px!important; text-align:center; line-height:120%!important } h1 a { font-size:28px!important; text-align:center } h2 a { font-size:24px!important; text-align:center } h3 a { font-size:18px!important; text-align:center } .es-menu td a { font-size:14px!important } .es-header-body p, .es-header-body ul li, .es-header-body ol li, .es-header-body a { font-size:16px!important } .es-footer-body p, .es-footer-body ul li, .es-footer-body ol li, .es-footer-body a { font-size:14px!important } .es-infoblock p, .es-infoblock ul li, .es-infoblock ol li, .es-infoblock a { font-size:12px!important } *[class="gmail-fix"] { display:none!important } .es-m-txt-c, .es-m-txt-c h1, .es-m-txt-c h2, .es-m-txt-c h3 { text-align:center!important } .es-m-txt-r, .es-m-txt-r h1, .es-m-txt-r h2, .es-m-txt-r h3 { text-align:right!important } .es-m-txt-l, .es-m-txt-l h1, .es-m-txt-l h2, .es-m-txt-l h3 { text-align:left!important } .es-m-txt-r img, .es-m-txt-c img, .es-m-txt-l img { display:inline!important } .es-button-border { display:b ...

# %%
def read_body(msg):
    # Необходимо, чтобы функция не принимала заглушки наподобие b' ' за текст
    # Это не мешает обойти систему послав очень длинную заглушку. Но это маловероятно
    body_len = 0
    
    if msg.is_multipart():
        for part in msg.walk():
            ctype = part.get_content_type()
            cdispo = str(part.get('Content-Disposition'))

            # Пропустить любые text/plain (txt) вложения
            if ctype == 'text/plain' and 'attachment' not in cdispo:
                if body_len < len(part.get_payload(decode=True)):
                    body = part.get_payload(decode=True)  # decode
                    body_len = len(body)
        # Письмо без деления на части. plain text без вложений. !Не дает гарантии, что это будет именно текст
        # может быть только вложение
    else:
        body = msg.get_payload(decode=True)
        
    return body.decode('utf-8','ignore')

# %%
body = read_body(msg)

# %%
body
# Out:
# 'new Дайджест >>\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0\u200c\u2005\xa0 ...

# %% [markdown]
# ### Не понятно, что делать с мусорными символами в начале. Возможно удалить фильтрацией. Но пока не нашел способа автоматического и без недостатков
#
# ! Данную работу должен осуществлять модуль предобработки данных

# %%
list(set(list(read_body(msg).encode("utf-8", "replace").decode("utf-8", "replace")[:300])))
# Out:
# ['\u200c',
#  'й',
#  '>',
#  '\xa0',
#  'а',
#  'т',
#  'д',
#  'e',
#  'е',
#  'ж',
#  '\u2005',
#  'n',
#  ' ',
#  'с',
#  'w',
#  'Д']

# %%
import re
reg = re.compile('[^a-zA-Zа-яА-Я0-9 ]')
print(reg.sub('', body))
# Out:
# new Дайджест  До 60 на пакетные предложения от SF Education SALE  Приветствую С вами на связи Роман Павлов ведущий вебинаров SF Education Делаем полезный перерыв в середине рабочего дня пройдите тест и узнайте как хорошо вы ориентируетесь в финансах А также приглашаю присоединиться к вебинарам этой недели Продуктивного дня и до встречи на вебинарах Анонсы SF Education Промо Никаких больше вечеринок Скидки на ВСЕкурсыдо 71 Подробнее С 11020 в SF Education повышаются цены на все курсы Последняя возможность получить востребованные навыки и знания выгодно Учитесь у признанных экспертов Вебинар 2309 в 2000 Лайфхаки в финансовом моделировании Регистрация Вебинар на основе курса Ивестиционный менеджер Подробнее о курсе Ярослав Малиновский  Инвестиционный аналитик АО Нацимбио ГК Ростех Вебинар 2409 в 2000 Доходная стратегия обзор рынков и инвестиционных решений Регистрация Вебинар на основе курса Ивестиционный менеджер Подробнее о курсе Дмитрий Абрамов  Директор Московского филиала БКС Брокер Артур Беджанов  Персональный брокер БКС Брокер Дмитрий Бланк  Начальник отдела инвестиционного консультирования БКС Брокер Вебинар 2609 в 1200 Презентация для инвестора Регистрация Вебинар на основе курса Венчурная академия Подробнее о курсе Денис Калышкин  Инвестиционный директор I2BF Global Ventures Вебинар 2609 в 1400 Инвестиционный банкинг в России текущая ситуация Регистрация Вебинар на основе курса Ивестиционный менеджер Подробнее о курсе Ярослав Малиновский  Инвестиционный аналитик АО Нацимбио ГК Ростех Успехов во всех начинаниях Команда SF Education  Copyright 2020 SF Education  191 186 Россия г СанктПетербург ул Большая Морская д 35 лит А пом 3Н294 оф 517 Вы получили данную рассылку так как являетесь клиентом или подписчиком SF Education Отказаться от рассылки
